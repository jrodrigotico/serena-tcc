# %% [markdown]
# # Pacoes e classes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funcoes.buscar_dados import Temperature, Load
from funcoes.equacoes import  tabela_equacoes
from funcoes.graficos import plot_metricas_por_hora, plot_cv_rmse_percent
from funcoes.funcoes_gerais import  trocar_temp
from funcoes.funcoes_teste import treinamento_estado, avaliar_modelo_por_hora_cv, treinamento_regioes_formatado
import datetime as dt


import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# credencias
api_key = '1a69aa1efefb4b73a592faf0e2fbe241'
start_date = "2020-01-01"
end_date = "2025-01-01"

# %%
# # Temperatura
# temp = Temperature(api_key)
# df_temp = temp.get_df_temp(start_date, end_date)
# df_temp.to_csv('df_temp2.csv')

# # # Carga
# load = Load(api_key)
# df_load = load.get_df_load(start_date, end_date)
# df_load.to_csv('df_load2.csv')

# %% [markdown]
# # Lendo arquivos baixados pela api
# filtrar de 2023/09 até 2024/09 todas as horas da carga

# %%
# df_t = pd.read_csv('C:/Users/joao.pinheiro/OneDrive - Serena/Área de Trabalho/df_temp.csv')
# df_l = pd.read_csv('C:/Users/joao.pinheiro/OneDrive - Serena/Área de Trabalho/df_load.csv')

df_t = pd.read_csv('C:/Users/Computadores Gamer/OneDrive/Área de Trabalho/dados_tcc/df_temp.csv')
df_l = pd.read_csv('C:/Users/Computadores Gamer/OneDrive/Área de Trabalho/dados_tcc/df_load.csv')

# %%
# Tratamentos iniciais
for df in [df_l, df_t]:
    df["interval_start_utc"] = pd.to_datetime(df["interval_start_utc"]).dt.tz_localize(None)
    df["interval_end_utc"] = pd.to_datetime(df["interval_end_utc"], utc=True).dt.tz_localize(None)
    df["publish_time_utc"] = pd.to_datetime(df["publish_time_utc"], utc=True).dt.tz_localize(None)
    
df_t = df_t.drop(columns=["Unnamed: 0"], errors="ignore")
df_l = df_l.drop(columns=["Unnamed: 0", "publish_time_utc_load",'publish_time_utc_tf'], errors="ignore")


df_t = df_t[['interval_start_utc', 'interval_end_utc', 'publish_time_utc', 'coast',
        'east', 'far_west', 'north', 'north_central', 'south_central',
        'southern', 'west', 'hour', 'weekday', 'avg_temp_fahrenheit']]

# Merge
df = pd.merge(
    df_l,
    df_t,
    on=["interval_start_utc", "interval_end_utc"],
    how="inner",
    suffixes=['_carga','_tf']
)

df = trocar_temp(df)
df['publish_time_utc_carga'] = pd.to_datetime(df['publish_time_utc_carga'])


hora = dt.time(10, 30) 
df = df[(df['publish_time_utc_carga'].dt.time == hora)]

# %% [markdown]
# # Criacao da coluna de temperatura ponderada pela populacao

# %%
# Dicionário de população por região
populacao_regioes = {
    'coast': 7077912,
    'east': 1562486,
    'far_west': 513422,
    'north': 1196299,
    'north_central': 9007898,
    'south_central': 4334575,
    'southern': 2337867,
    'west': 644082
}

# Lista das colunas de temperatura
colunas_temp = [f'{regiao}_tc' for regiao in populacao_regioes]

# Calcula o numerador (temperatura * população por região)
numerador = sum(df[col] * populacao_regioes[col.rsplit('_', 1)[0]] for col in colunas_temp)

# Soma total das populações
denominador = sum(populacao_regioes.values())

# Cria a nova coluna de temperatura ponderada
df['temp_ponderada_pop'] = numerador / denominador

# %% [markdown]
# # Teste 1
# y= f(x,weekday)= ax2 + bx + c⋅weekday + d

# %%
tabela1 = treinamento_estado(df, 'avg_temp_celsius', 'sum_load')
tabela1
# Out:
#     hora                          equacao  RMSE Treino  R² Treino  \
# 0      0  y = 91.09x² -2458.00x +55539.49  2145.321536   0.930215
# 1      1   y = -3.31x² +699.87x +33534.08  5790.750785   0.388553
# 2      2  y = 90.64x² -2452.75x +53475.24  1949.486911   0.916925
# 3      3  y = 89.99x² -2414.65x +52801.55  1891.980038   0.909083
# 4      4  y = 90.31x² -2426.14x +53218.21  1902.069864   0.895098
# 5      5  y = 91.28x² -2487.51x +55279.02  2124.132090   0.852701
# 6      6  y = 88.24x² -2459.14x +58045.52  2758.361342   0.725007
# 7      7  y = 86.05x² -2420.05x +59394.14  3015.427007   0.656595
# 8      8  y = 85.28x² -2400.44x +59979.81  2675.310744   0.759363
# 9      9  y = 90.16x² -2692.10x +64127.14  2473.186707   0.853826
# 10    10  y = 96.62x² -3019.59x +68041.32  2738.232853   0.886137
# 11    11  y = 99.75x² -3196.59x +69944.78  3210.422998   0.896435
# 12    12  y = 99.34x² -3219.71x +70200.39  3743.659342   0.897473
# 13    13  y = 99.18x² -3235.49x +70225.50  4276.708972   0.894175
# 14    14  y = 94.07x² -2991.50x +67266.21  4487.550580   0.899507
# 15    15  y = 94.07x² -3031.01x +67808.04  4694.587453   0.897999
# 16    16  y = 87.46x² -2746.69x +65276.78  4608.674404   0.902495
# 17    17  y = 84.87x² -2681.91x +66065.16  4449.650820   0.903127
# 18    18  y = 80.04x² -2509.78x +65728.14  3982.924452   0.908592
# 19    19  y = 79.06x² -2444.79x +65103.55  3393.510406   0.922047
# 20    20  y = 82.64x² -2454.80x +63967.51  2766.358424   0.939044
# 21    21  y = 88.06x² -2472.57x +62003.36  2785.701986   0.931166
# 22    22  y = 89.66x² -2449.28x +59516.80  2600.014955   0.929385
# 23    23  y = 90.68x² -2456.34x +57341.28  2457.450275   0.924796
#
#      RMSE Teste  R² Teste  RMSE Validação  R² Validação  CV RMSE Médio  \
# 0   1797.683717  0.948815     2045.598774      0.928700    2153.046441
# 1   4970.750118  0.526052     5731.672109      0.326714    8736.465964
# 2   1794.035655  0.926439     1922.061659      0.914100    1850.308789
# 3   1507.482849  0.938310     2001.389470      0.886560    2140.945882
# 4   1502.976947  0.928270     2088.647116      0.859618    2240.327857
# 5   1765.091083  0.883687     2337.707508      0.803167    2500.669982
# 6   2433.349055  0.745427     2948.716466      0.661367    3148.098679
# 7   2704.205505  0.674688     3208.858260      0.590198    3413.079176
# 8   2676.406677  0.761493     2448.949018      0.755376    2523.817018
# 9   2341.315794  0.868563     2344.564019      0.846501    2383.647035
# 10  2519.997589  0.903862     2627.810494      0.880791    2654.621200
# 11  2984.127776  0.911573     3204.511119      0.884620    3212.588559
# 12  3368.973179  0.920756     3856.418943      0.880250    3864.035530
# 13  3639.692031  0.923512     4302.035506      0.886131    4441.215454
# 14  4389.396609  0.889813     4148.174788      0.919404    4111.900392
# 15  4272.137524  0.909742     4587.604698      0.895380    4562.020661
# 16  4211.736057  0.906072     4507.657531      0.907950    4483.547939
# 17  4115.247697  0.905222     4198.569942      0.914884    4207.523541
# 18  3970.497933  0.913695     3883.560946      0.912286    3879.349988
# 19  3469.372415  0.913641     3516.704889      0.909661    3550.768377
# 20  2739.546517  0.936491     2875.163618      0.928239    2893.806291
# 21  2586.969074  0.936064     2732.712331      0.927537    2715.574684
# 22  2309.602318  0.939548     2537.558412      0.926374    2535.888584
# 23  2128.470903  0.938638     2422.162403      0.920472    2431.651721
#
#      CV RMSE DP  CV RMSE %
# 0    286.598871  13.311319
# 1   6706.725406  76.767030
# 2    359.706145  19.440331
# 3    385.651996  18.013159
# 4    377.188174  16.836294
# 5    321.673793  12.863504
# 6    377.992982  12.007025
# 7    461.635587  13.525487
# 8    242.662127   9.614886
# 9    148.711838   6.238836
# 10   188.932509   7.117117
# 11   429.560113  13.371152
# 12   360.249517   9.323142
# 13   615.984548  13.869729
# 14   695.726389  16.919826
# 15   806.393163  17.676228
# 16   423.353029   9.442366
# 17   238.670706   5.672475
# 18   709.319907  18.284504
# 19   479.545205  13.505392
# 20   400.608943  13.843668
# 21   428.328380  15.773029
# 22   433.547494  17.096473
# 23   384.470436  15.811082

# %%
df_resultado_estado1 = treinamento_estado(df, column_x='avg_temp_celsius', column_y='sum_load')
plot_metricas_por_hora(df_resultado_estado1)

# %%
plot_cv_rmse_percent(df_resultado_estado1)

# %% [markdown]
# # Teste 2

# %%
tabela2 = treinamento_estado(df, 'temp_ponderada_pop', 'sum_load')
tabela2
# Out:
#     hora                           equacao  RMSE Treino  R² Treino  \
# 0      0   y = 94.79x² -2645.81x +57320.77  2255.425679   0.922868
# 1      1    y = -5.37x² +778.64x +32598.72  5886.154778   0.368239
# 2      2   y = 92.93x² -2605.69x +55073.33  2061.293480   0.907122
# 3      3   y = 92.24x² -2573.97x +54488.13  1980.506073   0.900376
# 4      4   y = 91.52x² -2556.65x +54743.69  1984.309602   0.885830
# 5      5   y = 92.85x² -2640.58x +57064.25  2158.008100   0.847965
# 6      6   y = 90.19x² -2629.25x +60028.95  2739.284805   0.728797
# 7      7   y = 89.08x² -2634.34x +61770.04  2954.619103   0.670305
# 8      8   y = 89.48x² -2666.00x +62846.42  2620.862629   0.769058
# 9      9   y = 94.37x² -2959.14x +67199.49  2492.425756   0.851543
# 10    10   y = 98.95x² -3200.52x +70363.60  2813.494873   0.879792
# 11    11  y = 101.69x² -3333.93x +71670.16  3319.819496   0.889256
# 12    12  y = 101.84x² -3359.99x +71844.89  3817.022464   0.893415
# 13    13  y = 101.01x² -3327.15x +71311.11  4380.984623   0.888952
# 14    14   y = 95.05x² -3017.47x +67408.84  4601.327199   0.894346
# 15    15   y = 94.61x² -3013.99x +67329.59  4815.172109   0.892691
# 16    16   y = 86.08x² -2620.78x +63458.99  4653.934793   0.900570
# 17    17   y = 84.06x² -2591.37x +64793.85  4507.527865   0.900590
# 18    18   y = 81.71x² -2531.51x +65652.14  4053.720268   0.905313
# 19    19   y = 82.38x² -2544.70x +65902.00  3489.817415   0.917559
# 20    20   y = 88.59x² -2677.38x +65940.47  2836.124943   0.935930
# 21    21   y = 92.41x² -2650.76x +63645.90  2999.589542   0.920190
# 22    22   y = 93.88x² -2644.43x +61408.12  2820.683803   0.916890
# 23    23   y = 95.80x² -2692.41x +59544.13  2578.710673   0.917191
#
#      RMSE Teste  R² Teste  RMSE Validação  R² Validação  CV RMSE Médio  \
# 0   1907.850311  0.942350     2312.178644      0.908906    2463.313947
# 1   5126.587680  0.495869     5878.687250      0.291732    9337.705299
# 2   1970.092757  0.911293     2069.638278      0.900402    2016.932339
# 3   1650.871587  0.926016     2230.726688      0.859073    2382.505132
# 4   1635.969011  0.915014     2309.771232      0.828320    2456.577774
# 5   1826.333340  0.875476     2515.468756      0.772094    2651.660849
# 6   2441.771174  0.743662     3048.098596      0.638157    3235.885514
# 7   2663.992408  0.684291     3255.550386      0.578185    3442.141709
# 8   2533.067244  0.786356     2426.336713      0.759873    2499.980324
# 9   2286.939643  0.874597     2389.761897      0.840526    2426.967028
# 10  2537.388378  0.902530     2680.068355      0.876003    2701.245753
# 11  3060.516946  0.906988     3172.363430      0.886924    3159.655603
# 12  3529.210510  0.913038     4051.489298      0.867829    4072.633686
# 13  4095.006724  0.903178     4353.992251      0.883364    4480.787662
# 14  4708.441846  0.873212     4489.851784      0.905580    4450.493513
# 15  4391.149020  0.904643     4685.047181      0.890888    4683.776989
# 16  4615.619022  0.887194     4745.219995      0.897992    4711.779931
# 17  4486.398332  0.887355     4522.190338      0.901257    4527.953315
# 18  4278.044767  0.899807     3940.191017      0.909709    3927.199913
# 19  3546.785286  0.909744     3534.908617      0.908723    3593.913619
# 20  2722.558345  0.937276     2835.457149      0.930207    2855.859712
# 21  2666.564615  0.932069     2920.347887      0.917244    2909.704420
# 22  2500.671834  0.929132     2773.860647      0.912023    2798.588331
# 23  2248.969091  0.931494     2547.870362      0.912003    2563.981751
#
#      CV RMSE DP  CV RMSE %
# 0    401.014726  16.279481
# 1   7401.364700  79.263207
# 2    424.547429  21.049166
# 3    414.478305  17.396743
# 4    430.065932  17.506709
# 5    393.907597  14.855127
# 6    486.132590  15.023170
# 7    514.719180  14.953457
# 8    233.320930   9.332911
# 9    164.543974   6.779819
# 10   296.537030  10.977788
# 11   542.636515  17.173913
# 12   333.493675   8.188649
# 13   639.284519  14.267235
# 14   519.743135  11.678326
# 15   773.308100  16.510353
# 16   368.790427   7.826988
# 17   331.071518   7.311726
# 18   832.030443  21.186353
# 19   466.861062  12.990325
# 20   342.599602  11.996374
# 21   344.545663  11.841260
# 22   380.748865  13.605033
# 23   386.545685  15.075992

# %%
df_resultado_estado2 = treinamento_estado(df, column_x='temp_ponderada_pop', column_y='sum_load')
plot_metricas_por_hora(df_resultado_estado2)

# %%
plot_cv_rmse_percent(df_resultado_estado2)

# %% [markdown]
# # Teste 3 , uma tabela para cada regiao

# %%
tabela_formatada3 = treinamento_regioes_formatado(df)
tabela_formatada3
# Out:
#      hora         região                         equação  RMSE Treino  \
# 0       0          coast  y = 26.22x² -751.19x +15227.30   790.679255
# 1       0           east    y = 3.78x² -109.71x +2119.17   147.100806
# 2       0       far_west     y = 2.05x² -48.23x +6414.37   312.390841
# 3       0          north     y = 2.30x² -51.29x +1447.61   130.772009
# 4       0  north_central  y = 28.88x² -784.99x +15438.29  1050.269277
# ..    ...            ...                             ...          ...
# 187    23          north     y = 2.11x² -44.49x +1422.58   137.563135
# 188    23  north_central  y = 29.07x² -794.26x +16173.80  1198.684409
# 189    23  south_central   y = 15.37x² -401.52x +9152.42   661.813151
# 190    23       southern    y = 8.94x² -277.59x +5260.78   229.605593
# 191    23           west     y = 1.86x² -49.48x +1474.04   101.773582
#
#      R² Treino  RMSE Teste  R² Teste  RMSE Validação  R² Validação  \
# 0     0.873037  659.070029  0.910780      662.042813      0.901513
# 1     0.731911  120.935859  0.789585      144.344116      0.693243
# 2     0.425385  371.912603  0.379604      279.991057      0.362469
# 3     0.749407  128.173728  0.737005      128.782265      0.723511
# 4     0.870654  952.232507  0.884840      999.829208      0.869680
# ..         ...         ...       ...             ...           ...
# 187   0.768996  137.744655  0.735764      130.855457      0.773796
# 188   0.863143  996.975803  0.902083     1107.751792      0.870408
# 189   0.862036  629.086369  0.861750      719.492296      0.826594
# 190   0.896231  219.046707  0.897711      221.356705      0.895851
# 191   0.809166   96.010820  0.816175       98.224688      0.811139
#
#      CV RMSE Médio  CV RMSE DP  CV RMSE %
# 0       688.338827   85.327162  12.396099
# 1       151.164126   18.805511  12.440459
# 2       271.420629   14.371334   5.294857
# 3       126.625458   18.522021  14.627407
# 4      1066.142008  157.610749  14.783279
# ..             ...         ...        ...
# 187     124.339813   27.176793  21.856872
# 188    1091.490314  199.397307  18.268353
# 189     732.436545   82.232831  11.227298
# 190     216.151832   15.834931   7.325837
# 191     100.160933    5.712269   5.703091
#
# [192 rows x 12 columns]

# %%
df_resultado3 = avaliar_modelo_por_hora_cv(df)
df_resultado3.rename(columns={
            'rmse_treino': 'RMSE Treino',
            'rmse_teste': 'RMSE Teste',
            'rmse_validacao': 'RMSE Validação',
            'r2_treino': 'R² Treino',
            'r2_teste': 'R² Teste',
            'r2_validacao': 'R² Validação',
        }, inplace=True)

df_resultado3
# Out:
#     hora  RMSE Treino   RMSE Teste  RMSE Validação  R² Treino  R² Teste  \
# 0      0  2201.171179  2051.950629     2172.019015   0.925974  0.930570
# 1      1  5870.980567  4946.818468     5697.381291   0.366114  0.513560
# 2      2  2011.580307  2200.503191     2050.757695   0.911467  0.885726
# 3      3  1997.621535  2006.713600     1999.451251   0.897742  0.887785
# 4      4  2024.391246  2048.170329     2029.190310   0.880164  0.864143
# 5      5  2240.355125  2255.018250     2243.308319   0.834938  0.808111
# 6      6  2833.271615  2811.673270     2828.946215   0.708968  0.659381
# 7      7  3044.352141  3007.174124     3036.920420   0.650073  0.596833
# 8      8  2670.496519  2496.531834     2636.546489   0.759011  0.766817
# 9      9  2481.407292  2336.559836     2453.059102   0.851966  0.857434
# 10    10  2761.054446  2620.262062     2733.414781   0.883675  0.888163
# 11    11  3225.827105  3129.793080     3206.808224   0.895023  0.895986
# 12    12  3667.697539  3940.291645     3723.998304   0.901276  0.884628
# 13    13  4251.217075  4194.233707     4239.843708   0.895636  0.894148
# 14    14  4431.449924  4722.213200     4491.108799   0.900668  0.890047
# 15    15  4682.675635  4370.569186     4621.940705   0.896621  0.910886
# 16    16  4521.280515  4594.223355     4536.033909   0.904964  0.902217
# 17    17  4331.775446  4475.539704     4361.048069   0.907119  0.901373
# 18    18  3920.231344  4044.453043     3945.388589   0.912219  0.905175
# 19    19  3468.218542  3126.366650     3402.596886   0.918415  0.927314
# 20    20  2801.265283  2522.685645     2747.809731   0.937298  0.944071
# 21    21  2942.992257  2677.074290     2891.765566   0.922843  0.929253
# 22    22  2747.372107  2509.004508     2701.381780   0.920740  0.926673
# 23    23  2510.877400  2309.939804     2471.996892   0.921058  0.926154
#
#     R² Validação  CV RMSE Médio   CV RMSE DP  CV RMSE %
# 0       0.926877    2913.565835   124.844242   4.284929
# 1       0.394289    5422.439648  1013.927763  18.698738
# 2       0.906637    2765.921171   113.745304   4.112384
# 3       0.895934    2695.126894   124.705331   4.627067
# 4       0.877278    2741.358658   145.766112   5.317294
# 5       0.830244    2946.998852   180.511973   6.125281
# 6       0.700520    3501.919560   184.493111   5.268342
# 7       0.640958    3694.337937   155.444779   4.207649
# 8       0.760474    3297.982748   112.724967   3.417997
# 9       0.852994    2976.566880   175.165517   5.884817
# 10      0.884528    3312.219868   233.552645   7.051242
# 11      0.895208    3953.960497   222.964506   5.639017
# 12      0.897968    4663.808527   215.029573   4.610600
# 13      0.895392    5275.589487   290.102888   5.498966
# 14      0.898512    5595.126909   459.650603   8.215195
# 15      0.899500    5828.382536   539.314716   9.253248
# 16      0.904410    6138.926900   479.884581   7.817076
# 17      0.905960    5698.459442   441.378447   7.745575
# 18      0.910931    5315.463522   408.996811   7.694471
# 19      0.920076    4723.833287   374.117845   7.919794
# 20      0.938560    4120.099751   314.438481   7.631817
# 21      0.924033    3773.765258   210.696538   5.583191
# 22      0.921841    3426.026478   160.970224   4.698452
# 23      0.922006    3260.121376   167.107976   5.125821

# %%
def plot_metricas_por_hora(df_resultados):
    metricas = [
        'RMSE Treino', 'RMSE Teste', 'RMSE Validação',
        'R² Treino', 'R² Teste', 'R² Validação',
    ]

    fig, axes = plt.subplots(2, 3, figsize=(18, 8))
    axes = axes.flatten()

    for i, metrica in enumerate(metricas):
        ax = axes[i]
        sns.lineplot(data=df_resultados, x='hora', y=metrica, marker='o', ax=ax)
        ax.set_xlabel('Hora')
        ax.set_ylabel(metrica)
        ax.grid(True)

    plt.tight_layout()
    plt.show()
    
plot_metricas_por_hora(df_resultado3)

# %%
plot_cv_rmse_percent(df_resultado3)
